# %%
import sys
sys.path.append("../src/")
from modeldispatcher import MODELDISPATCHER
# Out:
# loaded pretrained model

# %%
from efficientnet import EfficientNet

# %%
model = EfficientNet.custom_head('efficientnet-b4', n_classes=5, pretrained=True)
DEVICE = "cuda"
model.to(DEVICE)

# %%
from torchsummary import summary
summary(model, input_size=(3, 137, 236))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#  Conv2dSamePadding-1          [-1, 48, 69, 118]           1,296
#        BatchNorm2d-2          [-1, 48, 69, 118]              96
#              Swish-3          [-1, 48, 69, 118]               0
#  Conv2dSamePadding-4          [-1, 48, 69, 118]             432
#        BatchNorm2d-5          [-1, 48, 69, 118]              96
#              Swish-6          [-1, 48, 69, 118]               0
#  Conv2dSamePadding-7             [-1, 12, 1, 1]             588
#              Swish-8             [-1, 12, 1, 1]               0
#  Conv2dSamePadding-9             [-1, 48, 1, 1]             624
# Conv2dSamePadding-10          [-1, 24, 69, 118]           1,152
#       BatchNorm2d-11          [-1, 24, 69, 118]              48
#       MBConvBlock-12          [-1, 24, 69, 118]               0
# Conv2dSamePadding-13          [-1, 24, 69, 118]             216
# ...

# %%
model = MODELDISPATCHER["efficientnet"]
DEVICE = "cuda"
model.to(DEVICE)
# Out:
# CustomHead(
#   (encoder): Encoder(
#     (stem_conv): Conv2dSamePadding(3, 48, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (stem_batch_norm): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     (stem_swish): Swish()
#     (blocks): ModuleList(
#       (0): MBConvBlock(
#         (swish): Swish()
#         (_depthwise_conv): Conv2dSamePadding(48, 48, kernel_size=(3, 3), stride=[1, 1], groups=48, bias=False)
#         (_bn1): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dSamePadding(48, 12, kernel_size=(1, 1), stride=(1, 1))
#         (_se_expand): Conv2dSamePadding(12, 48, kernel_size=(1, 1), stride=(1, 1))
#         (_project_conv): Conv2dSamePadding(48, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       )
# ...

# %%
summary(model, input_size=(3, 137, 236))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ead43190c74d> in <module>
# ----> 1 summary(model, input_size=(3, 137, 236))
#
# NameError: name 'summary' is not defined
